# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style("darkgrid")

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from sklearn.preprocessing import RobustScaler

# %%
file_paths = [
    "/kaggle/input/scaled-citylearn-aicrowd/scaled_b1.csv",
    "/kaggle/input/scaled-citylearn-aicrowd/scaled_b2.csv",
    "/kaggle/input/scaled-citylearn-aicrowd/scaled_b3.csv",
    "/kaggle/input/scaled-citylearn-aicrowd/scaled_cint.csv",
    "/kaggle/input/scaled-citylearn-aicrowd/scaled_pr.csv",
    "/kaggle/input/scaled-citylearn-aicrowd/scaled_weat.csv",
]

# Create a list of DataFrames by reading the CSV files
dataframes = [pd.read_csv(file_path) for file_path in file_paths]

for i, df in enumerate(dataframes):
    print(f"Shape of DataFrame {i + 1}: {df.shape}")

# %%
b1= pd.read_csv("/kaggle/input/scaled-citylearn-aicrowd/scaled_b1.csv")
b2=pd.read_csv("/kaggle/input/scaled-citylearn-aicrowd/scaled_b2.csv")
b3=pd.read_csv("/kaggle/input/scaled-citylearn-aicrowd/scaled_b3.csv")
cint=pd.read_csv("/kaggle/input/scaled-citylearn-aicrowd/scaled_cint.csv")
pr=pd.read_csv("/kaggle/input/scaled-citylearn-aicrowd/scaled_pr.csv")
weat=pd.read_csv("/kaggle/input/scaled-citylearn-aicrowd/scaled_weat.csv")

# %%
b1.head(2)

# %%
cint.head(2)

# %%
pr.head(2)

# %%
weat.head(2)

# %%
b123 = pd.concat([b1, b2,b3], axis=0)

# %%
b123.shape

# %%
res=pd.concat([b123,cint], axis=1)

# %%
res.shape

# %%
res.head(5)

# %%
res.reset_index(drop=True, inplace=True)

# %%
res.head(1400)

# %%
res.to_csv('res.csv', index=False)
